# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%EB%8A%94_%EC%B0%BD%EC%9D%98%EB%A0%A5%EC%9D%84_%EB%B0%9C%ED%9C%98%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84%EA%B9%8C%3F_GAN_(Fashion_MNIST).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[9장] 이미지 학습 기법 활용하기/3_9_2_AI는 창의력을 발휘할 수 있을까 - GAN/02 - Fashion MNIST
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[9장] 이미지 학습 기법 활용하기/3_9_2_AI는 창의력을 발휘할 수 있을까 - GAN/01 - MNIST

# %%
import data_reader
import gan

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 100  # 예제 기본값은 100입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# GAN을 불러옵니다.
# Generator
generator = gan.make_generator()
# Discriminator
discriminator = gan.make_discriminator()

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
gan.train(generator, discriminator, dr.train_dataset, EPOCHS)
# Out:
# Epoch 4   Generator Loss : 1.01170   Discriminator Loss : 1.19065   Time : 723.6 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-54878832dc86> in <module>()
#       1 # 인공신경망을 학습시킵니다.
#       2 print("\n\n************ TRAINING START ************ ")
# ----> 3 gan.train(generator, discriminator, dr.train_dataset, EPOCHS)
#
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[9장] 이미지 학습 기법 활용하기/3_9_2_AI는 창의력을 발휘할 수 있을까 - GAN/01 - MNIST/gan.py in train(generator, discriminator, dataset, epochs)
#     118         start = time.time()
#     119         for image_batch in dataset:
# --> 120             gen_loss, disc_loss = train_step(generator, discriminator, image_batch)
#     121         duration = time.time() - start
# ...

# %%
# GIF 애니메이션을 저장합니다.
gan.gif_generation()
