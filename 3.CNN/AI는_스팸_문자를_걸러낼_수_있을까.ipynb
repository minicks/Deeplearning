# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%E1%84%82%E1%85%B3%E1%86%AB_%E1%84%89%E1%85%B3%E1%84%91%E1%85%A2%E1%86%B7_%E1%84%86%E1%85%AE%E1%86%AB%E1%84%8C%E1%85%A1%E1%84%85%E1%85%B3%E1%86%AF_%E1%84%80%E1%85%A5%E1%86%AF%E1%84%85%E1%85%A5%E1%84%82%E1%85%A2%E1%86%AF_%E1%84%89%E1%85%AE_%E1%84%8B%E1%85%B5%E1%86%BB%E1%84%8B%E1%85%B3%E1%86%AF%E1%84%81%E1%85%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[4편] 인간의 기억력을 흉내 낸 인공지능 - LSTM/[11장] 자연어 학습 인공지능/4_11_1_AI는 스팸 문자를 걸러낼 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[4편] 인간의 기억력을 흉내 낸 인공지능 - LSTM/[11장] 자연어 학습 인공지능/4_11_1_AI는 스팸 문자를 걸러낼 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 50  # 예제 기본값은 50입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# Data Read Done!
# Training X Size : (4128, 189)
# Training Y Size : (4128,)
# Test X Size : (1032, 189)
# Test Y Size : (1032,)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Embedding(8983, 128),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer="adam", metrics=['accuracy'],
              loss="binary_crossentropy")

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/50
# 129/129 [==============================] - 3s 18ms/step - loss: 0.4346 - accuracy: 0.8609 - val_loss: 0.3558 - val_accuracy: 0.8731
# Epoch 2/50
# 129/129 [==============================] - 2s 16ms/step - loss: 0.3377 - accuracy: 0.8762 - val_loss: 0.3263 - val_accuracy: 0.8731
# Epoch 3/50
# 129/129 [==============================] - 2s 17ms/step - loss: 0.2843 - accuracy: 0.8765 - val_loss: 0.2386 - val_accuracy: 0.8731
# Epoch 4/50
# 129/129 [==============================] - 2s 17ms/step - loss: 0.1523 - accuracy: 0.9426 - val_loss: 0.1091 - val_accuracy: 0.9680
# Epoch 5/50
# 129/129 [==============================] - 2s 16ms/step - loss: 0.0681 - accuracy: 0.9801 - val_loss: 0.0754 - val_accuracy: 0.9738
# Epoch 6/50
# 129/129 [==============================] - 2s 16ms/step - loss: 0.0465 - accuracy: 0.9879 - val_loss: 0.0746 - val_accuracy: 0.9748
# Epoch 7/50
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 10  # 예제 기본값은 50입니다.

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Embedding(8983, 128),
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer="adam", metrics=['accuracy'],
              loss="binary_crossentropy")

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/10
# 129/129 [==============================] - 3s 17ms/step - loss: 0.4218 - accuracy: 0.8692 - val_loss: 0.3545 - val_accuracy: 0.8731
# Epoch 2/10
# 129/129 [==============================] - 2s 16ms/step - loss: 0.3334 - accuracy: 0.8762 - val_loss: 0.3163 - val_accuracy: 0.8731
# Epoch 3/10
# 129/129 [==============================] - 2s 15ms/step - loss: 0.2572 - accuracy: 0.8794 - val_loss: 0.2044 - val_accuracy: 0.9128
# Epoch 4/10
# 129/129 [==============================] - 2s 16ms/step - loss: 0.1347 - accuracy: 0.9525 - val_loss: 0.1038 - val_accuracy: 0.9671
# Epoch 5/10
# 129/129 [==============================] - 2s 15ms/step - loss: 0.0615 - accuracy: 0.9828 - val_loss: 0.0730 - val_accuracy: 0.9748
# Epoch 6/10
# 129/129 [==============================] - 2s 16ms/step - loss: 0.0439 - accuracy: 0.9864 - val_loss: 0.0634 - val_accuracy: 0.9787
# Epoch 7/10
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
