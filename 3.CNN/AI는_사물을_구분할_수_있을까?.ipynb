# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%EB%8A%94_%EC%82%AC%EB%AC%BC%EC%9D%84_%EA%B5%AC%EB%B6%84%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_2_AI는 사물을 구분할 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_2_AI는 사물을 구분할 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 20  # 예제 기본값은 20입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# ...
# 170500096/170498071 [==============================] - 4s 0us/step
#
#
# Data Read Done!
# Training X Size : (50000, 32, 32)
# Training Y Size : (50000, 1)
# Test X Size : (10000, 32, 32)
# Test Y Size : (10000, 1)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0595 - accuracy: 0.2517 - val_loss: 1.9637 - val_accuracy: 0.2916
# Epoch 2/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9190 - accuracy: 0.3139 - val_loss: 1.8793 - val_accuracy: 0.3394
# Epoch 3/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8625 - accuracy: 0.3368 - val_loss: 1.8632 - val_accuracy: 0.3372
# Epoch 4/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.8239 - accuracy: 0.3517 - val_loss: 1.8191 - val_accuracy: 0.3495
# Epoch 5/20
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.7931 - accuracy: 0.3643 - val_loss: 1.8017 - val_accuracy: 0.3666
# Epoch 6/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.7711 - accuracy: 0.3716 - val_loss: 1.8040 - val_accuracy: 0.3612
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.2205 - accuracy: 0.1577 - val_loss: 2.1319 - val_accuracy: 0.2107
# Epoch 2/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.1771 - accuracy: 0.1813 - val_loss: 2.1100 - val_accuracy: 0.2491
# Epoch 3/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.1624 - accuracy: 0.1861 - val_loss: 2.0893 - val_accuracy: 0.2473
# Epoch 4/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.1569 - accuracy: 0.1881 - val_loss: 2.0910 - val_accuracy: 0.2551
# Epoch 5/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.1421 - accuracy: 0.1951 - val_loss: 2.0709 - val_accuracy: 0.2570
# Epoch 6/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.1353 - accuracy: 0.1962 - val_loss: 2.0475 - val_accuracy: 0.2597
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32, 32)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.1870 - accuracy: 0.1773 - val_loss: 2.0696 - val_accuracy: 0.2381
# Epoch 2/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0649 - accuracy: 0.2437 - val_loss: 1.9658 - val_accuracy: 0.3023
# Epoch 3/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0189 - accuracy: 0.2632 - val_loss: 1.9326 - val_accuracy: 0.3046
# Epoch 4/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9921 - accuracy: 0.2753 - val_loss: 1.8979 - val_accuracy: 0.3204
# Epoch 5/20
# 1563/1563 [==============================] - 4s 3ms/step - loss: 1.9612 - accuracy: 0.2880 - val_loss: 1.8638 - val_accuracy: 0.3332
# Epoch 6/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.9434 - accuracy: 0.2940 - val_loss: 1.8788 - val_accuracy: 0.3282
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
