# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%EB%8A%94%20%EC%86%90%EA%B8%80%EC%94%A8%EB%A5%BC%20%EC%9D%B8%EC%8B%9D%ED%95%A0%20%EC%88%98%20%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_1_AI는 손글씨를 인식할 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_1_AI는 손글씨를 인식할 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 20  # 예제 기본값은 20입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step
#
#
# Data Read Done!
# Training X Size : (60000, 28, 28)
# Training Y Size : (60000,)
# Test X Size : (10000, 28, 28)
# Test Y Size : (10000,)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2580 - accuracy: 0.9261 - val_loss: 0.1424 - val_accuracy: 0.9572
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1112 - accuracy: 0.9671 - val_loss: 0.0947 - val_accuracy: 0.9718
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0782 - accuracy: 0.9765 - val_loss: 0.0797 - val_accuracy: 0.9748
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0580 - accuracy: 0.9819 - val_loss: 0.0944 - val_accuracy: 0.9701
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0453 - accuracy: 0.9858 - val_loss: 0.0698 - val_accuracy: 0.9784
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0353 - accuracy: 0.9888 - val_loss: 0.0699 - val_accuracy: 0.9782
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# #드롭아웃 사용

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3927 - accuracy: 0.8842 - val_loss: 0.1827 - val_accuracy: 0.9439
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2245 - accuracy: 0.9335 - val_loss: 0.1220 - val_accuracy: 0.9646
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1848 - accuracy: 0.9449 - val_loss: 0.1087 - val_accuracy: 0.9682
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1656 - accuracy: 0.9499 - val_loss: 0.1002 - val_accuracy: 0.9710
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1520 - accuracy: 0.9541 - val_loss: 0.0933 - val_accuracy: 0.9719
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1366 - accuracy: 0.9578 - val_loss: 0.0873 - val_accuracy: 0.9751
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
