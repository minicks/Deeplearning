# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%EB%8A%94_%EC%82%AC%EB%9E%8C%EA%B3%BC_%EB%A7%90%EC%9D%84_%EA%B5%AC%EB%B6%84%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_5_AI는 사람과 말을 구분할 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_5_AI는 사람과 말을 구분할 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 30  # 예제 기본값은 30입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# Reading Data...
# Opening human/
# Opening horse/
#
#
# Data Read Done!
# Training X Size : (822, 150, 150, 3)
# Training Y Size : (822,)
# Test X Size : (205, 150, 150, 3)
# Test Y Size : (205,)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1)
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='binary_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/30
# 26/26 [==============================] - 17s 620ms/step - loss: 0.9943 - accuracy: 0.5438 - val_loss: 0.5820 - val_accuracy: 0.6732
# Epoch 2/30
# 26/26 [==============================] - 16s 613ms/step - loss: 0.5075 - accuracy: 0.7676 - val_loss: 0.3815 - val_accuracy: 0.8390
# Epoch 3/30
# 26/26 [==============================] - 16s 618ms/step - loss: 0.2956 - accuracy: 0.9319 - val_loss: 0.5256 - val_accuracy: 0.9268
# Epoch 4/30
# 26/26 [==============================] - 16s 620ms/step - loss: 0.2751 - accuracy: 0.9501 - val_loss: 0.6546 - val_accuracy: 0.8976
# Epoch 5/30
# 26/26 [==============================] - 16s 606ms/step - loss: 0.5205 - accuracy: 0.8844 - val_loss: 0.2797 - val_accuracy: 0.9415
# Epoch 6/30
# 26/26 [==============================] - 16s 609ms/step - loss: 0.4399 - accuracy: 0.9185 - val_loss: 0.6267 - val_accuracy: 0.8195
# Epoch 7/30
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# #모델 축소

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1)
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='binary_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/30
# 26/26 [==============================] - 16s 609ms/step - loss: 1.6790 - accuracy: 0.5645 - val_loss: 0.5456 - val_accuracy: 0.5951
# Epoch 2/30
# 26/26 [==============================] - 16s 603ms/step - loss: 0.4665 - accuracy: 0.8540 - val_loss: 0.3184 - val_accuracy: 0.9366
# Epoch 3/30
# 26/26 [==============================] - 16s 601ms/step - loss: 0.7333 - accuracy: 0.8589 - val_loss: 0.7874 - val_accuracy: 0.7805
# Epoch 4/30
# 26/26 [==============================] - 16s 598ms/step - loss: 0.3618 - accuracy: 0.8966 - val_loss: 0.3158 - val_accuracy: 0.9366
# Epoch 5/30
# 26/26 [==============================] - 16s 601ms/step - loss: 0.1585 - accuracy: 0.9513 - val_loss: 0.2142 - val_accuracy: 0.9707
# Epoch 6/30
# 26/26 [==============================] - 16s 602ms/step - loss: 0.0891 - accuracy: 0.9793 - val_loss: 0.1856 - val_accuracy: 0.9756
# Epoch 7/30
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# # 모델 축소2

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1)
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='binary_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/30
# 26/26 [==============================] - 16s 575ms/step - loss: 7.4419 - accuracy: 0.4976 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 2/30
# 26/26 [==============================] - 15s 569ms/step - loss: 7.7359 - accuracy: 0.4927 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 3/30
# 26/26 [==============================] - 15s 572ms/step - loss: 7.7359 - accuracy: 0.4927 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 4/30
# 26/26 [==============================] - 15s 575ms/step - loss: 7.7359 - accuracy: 0.4927 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 5/30
# 26/26 [==============================] - 15s 573ms/step - loss: 7.7359 - accuracy: 0.4927 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 6/30
# 26/26 [==============================] - 15s 575ms/step - loss: 7.7359 - accuracy: 0.4927 - val_loss: 8.1825 - val_accuracy: 0.4634
# Epoch 7/30
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
