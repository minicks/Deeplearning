# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/CNN_AI%EB%8A%94_%EC%82%AC%EB%AC%BC%EC%9D%84_%EA%B5%AC%EB%B6%84%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_4_CNN AI는 사물을 구분할 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_4_CNN AI는 사물을 구분할 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 20  # 예제 기본값은 20입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# ...
# 170500096/170498071 [==============================] - 4s 0us/step
#
#
# Data Read Done!
# Training X Size : (50000, 32, 32, 3)
# Training Y Size : (50000, 1)
# Test X Size : (10000, 32, 32, 3)
# Test Y Size : (10000, 1)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1563/1563 [==============================] - 94s 59ms/step - loss: 1.4847 - accuracy: 0.4698 - val_loss: 1.2196 - val_accuracy: 0.5606
# Epoch 2/20
# 1563/1563 [==============================] - 92s 59ms/step - loss: 1.1470 - accuracy: 0.5945 - val_loss: 1.1864 - val_accuracy: 0.5922
# Epoch 3/20
# 1563/1563 [==============================] - 92s 59ms/step - loss: 1.0094 - accuracy: 0.6492 - val_loss: 0.9769 - val_accuracy: 0.6591
# Epoch 4/20
# 1563/1563 [==============================] - 92s 59ms/step - loss: 0.9144 - accuracy: 0.6847 - val_loss: 1.0436 - val_accuracy: 0.6347
# Epoch 5/20
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.8408 - accuracy: 0.7095 - val_loss: 0.9824 - val_accuracy: 0.6722
# Epoch 6/20
# 1563/1563 [==============================] - 91s 58ms/step - loss: 0.7862 - accuracy: 0.7304 - val_loss: 0.8357 - val_accuracy: 0.7095
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(rate=0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/20
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.5179 - accuracy: 0.4492 - val_loss: 1.2814 - val_accuracy: 0.5335
# Epoch 2/20
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.1700 - accuracy: 0.5861 - val_loss: 1.1634 - val_accuracy: 0.5856
# Epoch 3/20
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.0331 - accuracy: 0.6408 - val_loss: 1.0919 - val_accuracy: 0.6282
# Epoch 4/20
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.9458 - accuracy: 0.6707 - val_loss: 1.1139 - val_accuracy: 0.6315
# Epoch 5/20
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.8754 - accuracy: 0.6968 - val_loss: 0.9035 - val_accuracy: 0.6872
# Epoch 6/20
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.8289 - accuracy: 0.7143 - val_loss: 0.9414 - val_accuracy: 0.6665
# Epoch 7/20
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
