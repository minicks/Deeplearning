# %% [markdown]
# <a href="https://colab.research.google.com/github/minicks/Deeplearning/blob/main/3.CNN/AI%EB%8A%94_%EA%B0%80%EC%9C%84%EB%B0%94%EC%9C%84%EB%B3%B4%EB%A5%BC_%ED%95%A0_%EC%88%98_%EC%9E%88%EC%9D%84%EA%B9%8C%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_6_AI는 가위바위보를 할 수 있을까
# Out:
# /content/drive/MyDrive/수학·통계를 몰라도 이해할 수 있는 쉬운 딥러닝 코드 소스/[3편] 인간의 시각 처리를 흉내 낸 인공지능 - CNN/[8장] 이미지 분류(Classification) 기법 활용하기/3_8_6_AI는 가위바위보를 할 수 있을까

# %%
from tensorflow import keras
import data_reader

# %%
# 몇 에포크 만큼 학습을 시킬 것인지 결정합니다.
EPOCHS = 10  # 예제 기본값은 10입니다.

# %%
# 데이터를 읽어옵니다.
dr = data_reader.DataReader()
# Out:
# Reading Data...
# Opening paper/
# Opening rock/
# Opening scissors/
#
#
# Data Read Done!
# Training X Size : (2314, 150, 150, 3)
# Training Y Size : (2314,)
# Test X Size : (578, 150, 150, 3)
# Test Y Size : (578,)

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3, activation="softmax")
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/10
# 73/73 [==============================] - 49s 658ms/step - loss: 0.6770 - accuracy: 0.6716 - val_loss: 0.2432 - val_accuracy: 0.9066
# Epoch 2/10
# 73/73 [==============================] - 49s 669ms/step - loss: 0.0772 - accuracy: 0.9801 - val_loss: 0.0238 - val_accuracy: 1.0000
# Epoch 3/10
# 73/73 [==============================] - 49s 666ms/step - loss: 0.0236 - accuracy: 0.9948 - val_loss: 0.0089 - val_accuracy: 0.9965
# Epoch 4/10
# 73/73 [==============================] - 49s 667ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 8.3691e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 73/73 [==============================] - 49s 668ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 6.7057e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 73/73 [==============================] - 49s 667ms/step - loss: 2.7245e-04 - accuracy: 1.0000 - val_loss: 2.8069e-04 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# # 모델 축소

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3, activation="softmax")
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/10
# 73/73 [==============================] - 49s 664ms/step - loss: 0.4563 - accuracy: 0.7990 - val_loss: 0.0777 - val_accuracy: 0.9775
# Epoch 2/10
# 73/73 [==============================] - 48s 664ms/step - loss: 0.0285 - accuracy: 0.9922 - val_loss: 0.0586 - val_accuracy: 0.9758
# Epoch 3/10
# 73/73 [==============================] - 48s 663ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0048 - val_accuracy: 0.9965
# Epoch 4/10
# 73/73 [==============================] - 49s 666ms/step - loss: 3.6110e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 5/10
# 73/73 [==============================] - 49s 668ms/step - loss: 1.7871e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 6/10
# 73/73 [==============================] - 49s 667ms/step - loss: 1.2014e-04 - accuracy: 1.0000 - val_loss: 9.6626e-04 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# #모델 축소 2

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3, activation="softmax")
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/10
# 73/73 [==============================] - 46s 628ms/step - loss: 0.4897 - accuracy: 0.7874 - val_loss: 0.1114 - val_accuracy: 0.9567
# Epoch 2/10
# 73/73 [==============================] - 46s 628ms/step - loss: 0.0290 - accuracy: 0.9927 - val_loss: 0.0256 - val_accuracy: 0.9913
# Epoch 3/10
# 73/73 [==============================] - 46s 627ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.0064 - val_accuracy: 0.9983
# Epoch 4/10
# 73/73 [==============================] - 46s 628ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 5/10
# 73/73 [==============================] - 46s 627ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 6/10
# 73/73 [==============================] - 46s 627ms/step - loss: 2.8899e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)

# %% [markdown]
# # 모델 축소 3

# %%
# 인공신경망을 제작합니다.
model = keras.Sequential([
    keras.layers.Conv2D(16, (3, 3), activation="relu"),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(32, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(3, activation="softmax")
])

# %%
# 인공신경망을 컴파일합니다.
model.compile(optimizer='adam', metrics=['accuracy'],
              loss='sparse_categorical_crossentropy')

# %%
# 인공신경망을 학습시킵니다.
print("\n\n************ TRAINING START ************ ")
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(dr.train_X, dr.train_Y, epochs=EPOCHS,
                    validation_data=(dr.test_X, dr.test_Y),
                    callbacks=[early_stop])
# Out:
# ************ TRAINING START ************
# Epoch 1/10
# 73/73 [==============================] - 40s 538ms/step - loss: 1.1329 - accuracy: 0.7234 - val_loss: 0.1603 - val_accuracy: 0.9567
# Epoch 2/10
# 73/73 [==============================] - 40s 545ms/step - loss: 0.0528 - accuracy: 0.9875 - val_loss: 0.0316 - val_accuracy: 0.9931
# Epoch 3/10
# 73/73 [==============================] - 40s 546ms/step - loss: 0.0147 - accuracy: 0.9974 - val_loss: 0.0195 - val_accuracy: 0.9948
# Epoch 4/10
# 73/73 [==============================] - 40s 545ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9983
# Epoch 5/10
# 73/73 [==============================] - 40s 549ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 6/10
# 73/73 [==============================] - 40s 547ms/step - loss: 9.2068e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 7/10
# ...

# %%
# 학습 결과를 그래프로 출력합니다.
data_reader.draw_graph(history)
